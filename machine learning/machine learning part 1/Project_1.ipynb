# %% [markdown]
# # Notice:
# This project mainly consists of the code of EDA, Data Cleaning, Data Preprocessing, Feature Engineering and Feature selection in the future sections we are going to implement the main ML model
